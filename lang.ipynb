# %%
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from typing import Annotated, List, Dict

# %%
class State(TypedDict):
    user_query: str
    university_name: str
    rewritten_query: str
    context: str
    answer: str
    quality_passed: bool


def myfun(state: State):
    print(state['user_query'])

myfun(State)
# Out:
# __main__.State['user_query']

# %%
a = "-4"
if a:
    print("not empty")
else:
    print("empty")
# Out:
# not empty
